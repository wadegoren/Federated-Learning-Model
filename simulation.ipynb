# %%
# depending on your shell, you might need to add `\` before `[` and `]`.
# !pip install -q flwr[simulation]
# !pip install flwr_datasets[vision]
# Out:
# Requirement already satisfied: flwr_datasets[vision] in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.2)
# Requirement already satisfied: datasets<3.0.0,>=2.14.3 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flwr_datasets[vision]) (2.14.7)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flwr_datasets[vision]) (1.24.3)
# Requirement already satisfied: pillow>=6.2.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flwr_datasets[vision]) (10.1.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (0.5)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (0.3.7)
# Requirement already satisfied: pandas in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (4.66.1)
# Requirement already satisfied: xxhash in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (0.17.3)
# Requirement already satisfied: packaging in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (4.0.3)
# Requirement already satisfied: filelock in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.62.1->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas->datasets<3.0.0,>=2.14.3->flwr_datasets[vision]) (1.16.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader


class Net(nn.Module):
    def __init__(self, num_classes: int) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 4 * 4, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, num_classes)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train(net, trainloader, optim, epochs, device: str):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    net.train()
    for _ in range(epochs):
        for batch in trainloader:
            images, labels = batch["image"].to(device), batch["label"].to(device)
            optim.zero_grad()
            loss = criterion(net(images), labels)
            loss.backward()
            optim.step()


def test(net, testloader, device: str):
    """Validate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, loss = 0, 0.0
    net.eval()
    with torch.no_grad():
        for data in testloader:
            images, labels = data["image"].to(device), data["label"].to(device)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
    accuracy = correct / len(testloader.dataset)
    return loss, accuracy

# %%
from datasets import Dataset
from flwr_datasets import FederatedDataset
from datasets.utils.logging import disable_progress_bar

# Let's set a simulation involving a total of 10 clients
NUM_CLIENTS = 10

# Download MNIST dataset and partition the "train" partition (so one can be assigned to each client)
trainset = FederatedDataset(dataset="cifar10", partitioners={"train": NUM_CLIENTS})
# Let's keep the test set as is, and use it to evaluate the global model on the server
centralized_testset = trainset.load_full("test")

# %%
from torchvision.transforms import ToTensor, Normalize, Compose

def apply_transforms(batch):
    """Apply transformations for CIFAR-10 dataset"""

    # Transformation to convert images to tensors and apply normalization
    transforms = Compose([
        ToTensor(),  # Convert PIL Image to Tensor
        Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))  # Normalize image pixels to the range [-1, 1]
    ])

    # Apply transformation to each image in the batch
    batch["image"] = [transforms(img) for img in batch["image"]]

    return batch

# %%
# !pip install -U ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (8.17.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (5.13.0)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.1)
# Requirement already satisfied: stack-data in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.3)
# Requirement already satisfied: colorama in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.10)
# Requirement already satisfied: executing>=1.2.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\wadeg\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 4.2 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    --------------------------------------- 215.0/215.0 kB 12.8 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.3 MB 12.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.3 MB 9.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.3 MB 8.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10

# %%
import flwr as fl
from collections import OrderedDict
from typing import Dict, List, Tuple

from flwr.common import NDArrays, Scalar


class FlowerClient(fl.client.NumPyClient):
    def __init__(self, trainloader, valloader) -> None:
        super().__init__()

        self.trainloader = trainloader
        self.valloader = valloader
        self.model = Net(num_classes=10)
        # Determine device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)  # send model to device

    def set_parameters(self, parameters):
        """With the model paramters received from the server,
        overwrite the uninitialise model in this class with them."""

        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        # now replace the parameters
        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self, config: Dict[str, Scalar]):
        """Extract all model parameters and conver them to a list of
        NumPy arryas. The server doesn't work with PyTorch/TF/etc."""
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def fit(self, parameters, config):
        """This method train the model using the parameters sent by the
        server on the dataset of this client. At then end, the parameters
        of the locally trained model are communicated back to the server"""

        # copy parameters sent by the server into client's local model
        self.set_parameters(parameters)

        # read from config
        lr, epochs = config["lr"], config["epochs"]

        # Define the optimizer
        optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=0.9)

        # do local training
        train(self.model, self.trainloader, optim, epochs=epochs, device=self.device)

        # return the model parameters to the server as well as extra info (number of training examples in this case)
        return self.get_parameters({}), len(self.trainloader), {}

    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
        """Evaluate the model sent by the server on this client's
        local validation set. Then return performance metrics."""

        self.set_parameters(parameters)
        loss, accuracy = test(self.model, self.valloader, device=self.device)
        # send statistics back to the server
        return float(loss), len(self.valloader), {"accuracy": accuracy}

# %%
def get_evaluate_fn(centralized_testset: Dataset):
    """This is a function that returns a function. The returned
    function (i.e. `evaluate_fn`) will be executed by the strategy
    at the end of each round to evaluate the stat of the global
    model."""

    def evaluate_fn(server_round: int, parameters, config):
        """This function is executed by the strategy it will instantiate
        a model and replace its parameters with those from the global model.
        The, the model will be evaluate on the test set (recall this is the
        whole MNIST test set)."""

        model = Net(num_classes=10)

        # Determine device
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        model.to(device)  # send model to device

        # set parameters to the model
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)

        # Apply transform to dataset
        testset = centralized_testset.with_transform(apply_transforms)

        testloader = DataLoader(testset, batch_size=50)
        # call test
        loss, accuracy = test(model, testloader, device)
        return loss, {"accuracy": accuracy}

    return evaluate_fn

# %%
from flwr.common import Metrics


def fit_config(server_round: int) -> Dict[str, Scalar]:
    """Return a configuration with static batch size and (local) epochs."""
    config = {
        "epochs": 1,  # Number of local epochs done by clients
        "lr": 0.01,  # Learning rate to use by clients during fit()
    }
    return config


def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    """Aggregation function for (federated) evaluation metrics, i.e. those returned by
    the client's evaluate() method."""
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
strategy = fl.server.strategy.FedAvg(
    fraction_fit=0.1,  # Sample 10% of available clients for training
    fraction_evaluate=0.05,  # Sample 5% of available clients for evaluation
    on_fit_config_fn=fit_config,
    evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
    evaluate_fn=get_evaluate_fn(centralized_testset),  # global evaluation function
)

# %%
from torch.utils.data import DataLoader


def get_client_fn(dataset: FederatedDataset):
    """Return a function to construct a client.

    The VirtualClientEngine will execute this function whenever a client is sampled by
    the strategy to participate.
    """

    def client_fn(cid: str) -> fl.client.Client:
        """Construct a FlowerClient with its own dataset partition."""

        # Let's get the partition corresponding to the i-th client
        client_dataset = dataset.load_partition(int(cid), "train")

        # Now let's split it into train (90%) and validation (10%)
        client_dataset_splits = client_dataset.train_test_split(test_size=0.1)

        trainset = client_dataset_splits["train"]
        valset = client_dataset_splits["test"]

        # Now we apply the transform to each batch.
        trainloader = DataLoader(
            trainset.with_transform(apply_transforms), batch_size=32, shuffle=True
        )
        trainset = DataLoader(valset.with_transform(apply_transforms), batch_size=32)

        # Create and return client
        return FlowerClient(trainloader, trainset).to_client()

    return client_fn


client_fn_callback = get_client_fn(trainset)

# %%
from datasets.utils.logging import disable_progress_bar
# With a dictionary, you tell Flower's VirtualClientEngine that each
# client needs exclusive access to these many resources in order to run
client_resources = {"num_cpus": 1, "num_gpus": 0.3}

# Let's disable tqdm progress bar in the main thread (used by the server)
disable_progress_bar()

history = fl.simulation.start_simulation(
    client_fn=client_fn_callback,  # a callback to construct a client
    num_clients=NUM_CLIENTS,  # total number of clients in the experiment
    config=fl.server.ServerConfig(num_rounds=10),  # let's run for 10 rounds
    strategy=strategy,  # the strategy that will orchestrate the whole FL pipeline
    client_resources=client_resources,
    actor_kwargs={
        "on_actor_init_fn": disable_progress_bar  # disable tqdm on each actor/process spawning virtual clients
    },
)
# Out:
# INFO flwr 2024-02-13 11:53:09,972 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[29], line 9
#       6 # Let's disable tqdm progress bar in the main thread (used by the server)
#       7 disable_progress_bar()
# ----> 9 history = fl.simulation.start_simulation(
#      10     client_fn=client_fn_callback,  # a callback to construct a client
#      11     num_clients=NUM_CLIENTS,  # total number of clients in the experiment
#      12     config=fl.server.ServerConfig(num_rounds=10),  # let's run for 10 rounds
#      13     strategy=strategy,  # the strategy that will orchestrate the whole FL pipeline
#      14     client_resources=client_resources,
#      15     actor_kwargs={
#      16         "on_actor_init_fn": disable_progress_bar  # disable tqdm on each actor/process spawning virtual clients
#      17     },
#      18 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\flwr\simulation\app.py:211, in start_simulation(client_fn, num_clients, clients_ids, client_resources, server, config, strategy, client_manager, ray_init_args, keep_initialised, actor_type, actor_kwargs, actor_scheduling)
#     208     ray.shutdown()
#     210 # Initialize Ray
# --> 211 ray.init(**ray_init_args)
#     212 cluster_resources = ray.cluster_resources()
#     213 log(
#     214     INFO,
#     215     "Flower VCE: Ray initialized with resources: %s",
#     216     cluster_resources,
#     217 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\worker.py:1514, in init(address, num_cpus, num_gpus, resources, labels, object_store_memory, local_mode, ignore_reinit_error, include_dashboard, dashboard_host, dashboard_port, job_config, configure_logging, logging_level, logging_format, log_to_driver, namespace, runtime_env, storage, **kwargs)
#    1480     ray_params = ray._private.parameter.RayParams(
#    1481         node_ip_address=node_ip_address,
#    1482         raylet_ip_address=raylet_ip_address,
#    (...)
#    1508         node_name=_node_name,
#    1509     )
#    1510     # Start the Ray processes. We set shutdown_at_exit=False because we
#    1511     # shutdown the node in the ray.shutdown call that happens in the atexit
#    1512     # handler. We still spawn a reaper process in case the atexit handler
#    1513     # isn't called.
# -> 1514     _global_node = ray._private.node.Node(
#    1515         head=True,
#    1516         shutdown_at_exit=False,
#    1517         spawn_reaper=True,
#    1518         ray_params=ray_params,
#    1519     )
#    1520 else:
#    1521     # In this case, we are connecting to an existing cluster.
#    1522     if num_cpus is not None or num_gpus is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\node.py:287, in Node.__init__(self, ray_params, head, shutdown_at_exit, spawn_reaper, connect_only, default_worker)
#     285 # Start processes.
#     286 if head:
# --> 287     self.start_head_processes()
#     289 if not connect_only:
#     290     self.start_ray_processes()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\node.py:1165, in Node.start_head_processes(self)
#    1162 self._write_cluster_info_to_kv()
#    1164 if not self._ray_params.no_monitor:
# -> 1165     self.start_monitor()
#    1167 if self._ray_params.ray_client_server_port:
#    1168     self.start_ray_client_server()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\node.py:1068, in Node.start_monitor(self)
#    1061 """Start the monitor.
#    1062
#    1063 Autoscaling output goes to these monitor.err/out files, and
#    1064 any modification to these files may break existing
#    1065 cluster launching commands.
#    1066 """
#    1067 stdout_file, stderr_file = self.get_log_file_handles("monitor", unique=True)
# -> 1068 process_info = ray._private.services.start_monitor(
#    1069     self.gcs_address,
#    1070     self._logs_dir,
#    1071     stdout_file=stdout_file,
#    1072     stderr_file=stderr_file,
#    1073     autoscaling_config=self._ray_params.autoscaling_config,
#    1074     fate_share=self.kernel_fate_share,
#    1075     max_bytes=self.max_bytes,
#    1076     backup_count=self.backup_count,
#    1077     monitor_ip=self._node_ip_address,
#    1078 )
#    1079 assert ray_constants.PROCESS_TYPE_MONITOR not in self.all_processes
#    1080 self.all_processes[ray_constants.PROCESS_TYPE_MONITOR] = [process_info]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\services.py:1963, in start_monitor(gcs_address, logs_dir, stdout_file, stderr_file, autoscaling_config, fate_share, max_bytes, backup_count, monitor_ip)
#    1961 if monitor_ip:
#    1962     command.append("--monitor-ip=" + monitor_ip)
# -> 1963 process_info = start_ray_process(
#    1964     command,
#    1965     ray_constants.PROCESS_TYPE_MONITOR,
#    1966     stdout_file=stdout_file,
#    1967     stderr_file=stderr_file,
#    1968     fate_share=fate_share,
#    1969 )
#    1970 return process_info
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\services.py:904, in start_ray_process(command, process_type, fate_share, env_updates, cwd, use_valgrind, use_gdb, use_valgrind_profiler, use_perftools_profiler, use_tmux, stdout_file, stderr_file, pipe_stdin)
#     902 if win32_fate_sharing:
#     903     try:
# --> 904         ray._private.utils.set_kill_child_on_death_win32(process)
#     905         psutil.Process(process.pid).resume()
#     906     except (psutil.Error, OSError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ray\_private\utils.py:908, in set_kill_child_on_death_win32(child_proc)
#     905     if not win32_AssignProcessToJobObject(win32_job, int(child_proc)):
#     906         import ctypes
# --> 908         raise OSError(ctypes.get_last_error(), "AssignProcessToJobObject() failed")
#     909 else:
#     910     assert False, "AssignProcessToJobObject used despite being unavailable"
#
# OSError: [Errno 203] AssignProcessToJobObject() failed

# %%
import matplotlib.pyplot as plt

print(f"{history.metrics_centralized = }")

global_accuracy_centralised = history.metrics_centralized["accuracy"]
round = [data[0] for data in global_accuracy_centralised]
acc = [100.0 * data[1] for data in global_accuracy_centralised]
plt.plot(round, acc)
plt.grid()
plt.ylabel("Accuracy (%)")
plt.xlabel("Round")
plt.title("CIFAR10 - IID - 10 clients with 10 clients per round") # Change clients per round
